# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRanker
from sklearn.metrics import mean_absolute_error as mae
import matplotlib.pyplot as plt
import seaborn as sns
from preprocess import preprocess, process, league_train_test_split, league_fusion, league_split, league_cross_val

# %% [markdown]
# # Data

# %%
data = pd.read_csv('jobfair_train.csv')

# %%
data
# Out:
#        season   club_id  league_id dynamic_payment_segment  cohort_season  \
# 0         173   6042825    2912348               2) Minnow            134
# 1         173   9620967    2912140               2) Minnow             28
# 2         173   6045474    2912933                4) Whale            136
# 3         173  14187773    2910371             0) NonPayer              2
# 4         173  13694853    2907632             0) NonPayer              5
# ...       ...       ...        ...                     ...            ...
# 55309     173  14278145    2906514             0) NonPayer              2
# 55310     173  14309556    2906913               2) Minnow              2
# 55311     173  14455654    2905985             0) NonPayer              1
# 55312     173  13623733    2910437             0) NonPayer              5
# 55313     173  11719971    2910381             0) NonPayer             16
#
#        avg_age_top_11_players  avg_stars_top_11_players  \
# 0                          25                  5.255151
# 1                          23                  4.962521
# 2                          23                 11.105782
# 3                          21                  4.164848
# 4                          22                  3.031939
# ...                       ...                       ...
# 55309                      25                  4.160909
# 55310                      21                  4.244145
# 55311                      21                  4.000158
# 55312                      24                  4.582158
# 55313                      23                  5.176582
#
#        avg_stars_top_14_players  avg_training_factor_top_11_players  \
# 0                      4.483009                            1.778801
# 1                      4.785648                           -0.002687
# 2                     10.511133                            0.628794
# 3                      4.023486                            0.551904
# 4                      2.926029                            0.690544
# ...                         ...                                 ...
# 55309                  3.948086                            0.503241
# 55310                  3.762286                            0.664514
# 55311                  3.753276                            0.507620
# 55312                  4.461391                            0.664767
# 55313                  4.762305                            0.640298
#
#        days_active_last_28_days  ...  registration_country  \
# 0                            25  ...              Portugal
# 1                            28  ...                Turkey
# 2                            28  ...               Belgium
# 3                            12  ...              Malaysia
# 4                             0  ...                 Italy
# ...                         ...  ...                   ...
# 55309                        11  ...           Switzerland
# 55310                        28  ...                France
# 55311                         6  ...                France
# 55312                        28  ...               Morocco
# 55313                         1  ...                Greece
#
#        registration_platform_specific  league_match_won_count_last_28_days  \
# 0                     Flash FB Canvas                                   24
# 1                       Android Phone                                   19
# 2                     Flash FB Canvas                                   26
# 3                       Android Phone                                   11
# 4                           iOS Phone                                    9
# ...                               ...                                  ...
# 55309                       iOS Phone                                   13
# 55310                       iOS Phone                                   25
# 55311                      iOS Tablet                                   14
# 55312                   Android Phone                                   22
# 55313                   Android Phone                                    6
#
#       training_count_last_28_days global_competition_level  \
# 0                             435                     11.0
# 1                              58                      7.0
# 2                             116                      8.0
# 3                              22                      2.0
# 4                               0                      4.0
# ...                           ...                      ...
# 55309                          25                      NaN
# 55310                         167                      NaN
# 55311                          17                      NaN
# 55312                          80                      4.0
# 55313                           2                      6.0
#
#        tokens_spent_last_28_days  tokens_stash  rests_stash  \
# 0                            598           245          186
# 1                            269             0           35
# 2                          23180           369          444
# 3                             41            43          213
# 4                              0            16          100
# ...                          ...           ...          ...
# 55309                         42            10           25
# 55310                        214           158          358
# 55311                         73            11           70
# 55312                         90            65          109
# 55313                         50            24           17
#
#        morale_boosters_stash  league_rank
# 0                        818            2
# 1                         24            2
# 2                       4933            1
# 3                        126            6
# 4                        147           10
# ...                      ...          ...
# 55309                     37            1
# 55310                    256            1
# 55311                     57           11
# 55312                    150            5
# 55313                    354            9
#
# [55314 rows x 23 columns]

# %%
data = data.sort_values(by='league_id')

# %%
data.head()
# Out:
#        season   club_id  league_id dynamic_payment_segment  cohort_season  \
# 17008     173  14438136    2904743             0) NonPayer              1
# 17232     173  14487784    2904743             0) NonPayer              1
# 17219     173  14478979    2904743             0) NonPayer              1
# 17205     173  14437898    2904743             0) NonPayer              1
# 17185     173  14496777    2904743             0) NonPayer              1
#
#        avg_age_top_11_players  avg_stars_top_11_players  \
# 17008                      24                  3.179297
# 17232                      24                  3.045430
# 17219                      23                  3.920945
# 17205                      21                  3.936582
# 17185                      23                  3.140812
#
#        avg_stars_top_14_players  avg_training_factor_top_11_players  \
# 17008                  3.038181                            0.721519
# 17232                  2.914638                            0.593801
# 17219                  3.658000                            0.552545
# 17205                  3.678486                            0.530063
# 17185                  3.002486                            0.608834
#
#        days_active_last_28_days  ...  registration_country  \
# 17008                         2  ...               Nigeria
# 17232                         2  ...                Mexico
# 17219                        12  ...                Turkey
# 17205                         3  ...                Brazil
# 17185                         2  ...               Armenia
#
#        registration_platform_specific  league_match_won_count_last_28_days  \
# 17008                       iOS Phone                                   10
# 17232                       iOS Phone                                    4
# 17219                   Android Phone                                    9
# 17205                   Android Phone                                   11
# 17185                   Android Phone                                    0
#
#       training_count_last_28_days global_competition_level  \
# 17008                           2                      NaN
# 17232                           1                      NaN
# 17219                          24                      NaN
# 17205                          24                      3.0
# 17185                           3                      NaN
#
#        tokens_spent_last_28_days  tokens_stash  rests_stash  \
# 17008                          2            53           22
# 17232                          2            43           42
# 17219                         91             3           16
# 17205                         65            21           17
# 17185                          9            47           42
#
#        morale_boosters_stash  league_rank
# 17008                     35           10
# 17232                     24           14
# 17219                      7            5
# 17205                     59            4
# 17185                     22           12
#
# [5 rows x 23 columns]

# %% [markdown]
# # Data split

# %%
X = data.drop('league_rank', axis=1)
y = data['league_rank']

# %%
X_train, X_test, y_train, y_test = league_train_test_split(X, y)

# %%
X_train = preprocess(X_train, y_train)
X_test = process(X_test)

# %%
group_data = X_train.groupby('league_id').size().values

# %%
X_train.drop(['league_id', 'season', 'club_id'], inplace=True, axis=1)
X_test.drop(['league_id', 'season', 'club_id'], inplace=True, axis=1)

# %% [markdown]
# # Model

# %%
ranker = XGBRanker(objective='rank:ndcg', device='cuda')

# %%
ranker.fit(X_train, y_train, group=group_data)
ranker.set_params(device='cpu')
# Out:
# XGBRanker(base_score=None, booster=None, callbacks=None, colsample_bylevel=None,
#           colsample_bynode=None, colsample_bytree=None, device='cpu',
#           early_stopping_rounds=None, enable_categorical=False,
#           eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#           importance_type=None, interaction_constraints=None,
#           learning_rate=None, max_bin=None, max_cat_threshold=None,
#           max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#           max_leaves=None, min_child_weight=None, missing=nan,
#           monotone_constraints=None, multi_strategy=None, n_estimators=None,
#           n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
y_train_pred = ranker.predict(X_train)

# %%
for i in range(0, y_train_pred.shape[0], 14):
    y_train_pred[i:i+14] = np.argsort(y_train_pred[i:i+14])

# %%
mae(y_train, y_train_pred)
# Out:
# 4.52971234747368

# %%
y_test_pred = pd.DataFrame()
predicted_scores = ranker.predict(X_test)
y_test_pred['predicted_scores'] = predicted_scores
y_test_pred['league_id'] = data['league_id'].iloc[X_test.index].values
y_test_pred['predicted_rank'] = y_test_pred.groupby('league_id')['predicted_scores'].rank(ascending=False, method='first')

# %%
y_test_pred['predicted_rank']
# Out:
# 0        3.0
# 1       14.0
# 2        5.0
# 3        7.0
# 4        1.0
#         ...
# 9907     1.0
# 9908    13.0
# 9909    12.0
# 9910    10.0
# 9911    14.0
# Name: predicted_rank, Length: 9912, dtype: float64

# %%
my_y_test_pred = ranker.predict(X_test)
for i in range(0, my_y_test_pred.shape[0], 14):
    my_y_test_pred[i:i+14] = np.argsort(my_y_test_pred[i:i+14])

# %%
my_y_test_pred
# Out:
# array([ 1.,  5., 13., ...,  6.,  7.,  9.], dtype=float32)

# %%
mae(y_test, y_test_pred['predicted_rank'])
# Out:
# 6.45137207425343

# %%
mae(y_test, my_y_test_pred)
# Out:
# 4.5258272800645685

# %%
y_test_pred.iloc[:14]
# Out:
#     predicted_scores  league_id  predicted_rank
# 0           0.904927    2904743             3.0
# 1          -3.309383    2904743            14.0
# 2           0.478665    2904743             5.0
# 3           0.152457    2904743             7.0
# 4           1.457854    2904743             1.0
# 5          -2.978901    2904743            13.0
# 6           0.721618    2904743             4.0
# 7           0.408883    2904743             6.0
# 8           1.134933    2904743             2.0
# 9          -0.943451    2904743            10.0
# 10         -0.825964    2904743             9.0
# 11         -1.294558    2904743            11.0
# 12         -0.628682    2904743             8.0
# 13         -1.347802    2904743            12.0

# %%
ranker.predict(X_test)[:14]
# Out:
# array([ 0.9049271 , -3.3093832 ,  0.47866464,  0.15245706,  1.4578536 ,
#        -2.9789011 ,  0.7216177 ,  0.40888348,  1.1349329 , -0.94345134,
#        -0.82596445, -1.2945577 , -0.62868166, -1.3478018 ], dtype=float32)
